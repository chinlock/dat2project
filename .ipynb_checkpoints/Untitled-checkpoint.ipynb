# %% [markdown]
# ## Step 1: Acquire data
#
# I am using the jobs data from indeed.com, with a search on "data scientist" for jobs located in Singapore.
#
# To acquire jobs data, I used the "indeed" package.  More information about the package can be found [here](https://github.com/indeedlabs/indeed-python)

# %%
from indeed import IndeedClient

client = IndeedClient(publisher = '1892653611555585')  # my publisher number

params = {
    'q' : "data scientist",
    'l' : "",
    'userip' : "1.2.3.4",
    'useragent' : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2)",
    'format' : "json",
    'co' : "singapore"
}

search_response = client.search(**params)

search_response
# Out:
# {u'dupefilter': True,
#  u'end': 10,
#  u'highlight': True,
#  u'location': u'',
#  u'pageNumber': 0,
#  u'paginationPayload': u'',
#  u'query': u'data scientist',
#  u'results': [{u'city': u'New York',
#    u'company': u'Knewton',
#    u'country': u'US',
#    u'date': u'Fri, 26 Aug 2016 02:37:51 GMT',
#    u'expired': False,
#    u'formattedLocation': u'New York, NY',
#    u'formattedLocationFull': u'New York, NY 10003',
#    u'formattedRelativeTime': u'30+ days ago',
#    u'indeedApply': False,
#    u'jobkey': u'39367ef1068a38e6',
#    u'jobtitle': u'Data Science Internship',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'You will join a world-class team of <b>data</b> <b>scientists</b> and engineers who are pushing the boundaries of machine learning....',
#    u'source': u'Knewton',
#    u'sponsored': False,
#    u'state': u'NY',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=39367ef1068a38e6&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Madison',
#    u'company': u'American Family Insurance',
#    u'country': u'US',
#    u'date': u'Mon, 18 Jul 2016 17:36:22 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Madison, WI',
#    u'formattedLocationFull': u'Madison, WI',
#    u'formattedRelativeTime': u'30+ days ago',
#    u'indeedApply': False,
#    u'jobkey': u'495ef16ebef75931',
#    u'jobtitle': u'Statistical Research Scientist',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'Provides guidance and direction related to <b>data</b> research and advanced analytics to Strategic <b>Data</b> &amp; Analytics staff as needed....',
#    u'source': u'American Family Insurance',
#    u'sponsored': False,
#    u'state': u'WI',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=495ef16ebef75931&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Seattle',
#    u'company': u'Google',
#    u'country': u'US',
#    u'date': u'Mon, 19 Sep 2016 09:48:25 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Seattle, WA',
#    u'formattedLocationFull': u'Seattle, WA',
#    u'formattedRelativeTime': u'30+ days ago',
#    u'indeedApply': False,
#    u'jobkey': u'053bbff2f7559d62',
#    u'jobtitle': u'Data Scientist / Quantitative Analyst, Engineering',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'4 years of relevant work experience (e.g., as a statistician / computational biologist / bioinformatician / <b>data</b> <b>scientist</b>), including deep expertise and...',
#    u'source': u'Google',
#    u'sponsored': False,
#    u'state': u'WA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=053bbff2f7559d62&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Santa Monica',
#    u'company': u'Tastemade',
#    u'country': u'US',
#    u'date': u'Tue, 08 Nov 2016 20:34:18 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Santa Monica, CA',
#    u'formattedLocationFull': u'Santa Monica, CA',
#    u'formattedRelativeTime': u'7 days ago',
#    u'indeedApply': True,
#    u'jobkey': u'2519820c6a28bd8f',
#    u'jobtitle': u'Data Scientist',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'As a <b>Data</b> <b>Scientist</b>, you will solve problems including, but not limited to:. <b>Data</b> is the biggest focus area at Tastemade right now....',
#    u'source': u'Tastemade',
#    u'sponsored': False,
#    u'state': u'CA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=2519820c6a28bd8f&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Santa Clara',
#    u'company': u'Intel',
#    u'country': u'US',
#    u'date': u'Wed, 09 Nov 2016 05:21:34 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Santa Clara, CA',
#    u'formattedLocationFull': u'Santa Clara, CA 95052',
#    u'formattedRelativeTime': u'6 days ago',
#    u'indeedApply': False,
#    u'jobkey': u'e938e7fdb4f1bab5',
#    u'jobtitle': u'Data Scientist',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'Background in deep learning, machine learning &amp; big <b>data</b>. Developing our Deep Learning framework. Cutting edge problems in applied AI and ML in one or more of...',
#    u'source': u'Intel',
#    u'sponsored': False,
#    u'state': u'CA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=e938e7fdb4f1bab5&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Eagan',
#    u'company': u'Ecolab',
#    u'country': u'US',
#    u'date': u'Wed, 26 Oct 2016 01:49:28 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Eagan, MN',
#    u'formattedLocationFull': u'Eagan, MN',
#    u'formattedRelativeTime': u'20 days ago',
#    u'indeedApply': False,
#    u'jobkey': u'eeba00ef694b5897',
#    u'jobtitle': u'Data Scientist',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'Ecolab is looking for a talented <b>data</b> <b>scientist</b> to work in a start-up like in-house innovation hub chartered with creating big <b>data</b> analytics and <b>data</b> science...',
#    u'source': u'Ecolab',
#    u'sponsored': False,
#    u'state': u'MN',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=eeba00ef694b5897&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Seattle',
#    u'company': u'Big Fish',
#    u'country': u'US',
#    u'date': u'Fri, 11 Nov 2016 02:04:50 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Seattle, WA',
#    u'formattedLocationFull': u'Seattle, WA',
#    u'formattedRelativeTime': u'4 days ago',
#    u'indeedApply': False,
#    u'jobkey': u'a3a698868b9b8761',
#    u'jobtitle': u'Data Scientist I',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'The <b>Data</b> <b>Scientists</b> are responsible for applying a wide variety of statistical and analytical techniques to business problems to glean valuable insights in...',
#    u'source': u'Big Fish',
#    u'sponsored': False,
#    u'state': u'WA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=a3a698868b9b8761&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'San Diego',
#    u'company': u'Intel',
#    u'country': u'US',
#    u'date': u'Tue, 08 Nov 2016 05:20:52 GMT',
#    u'expired': False,
#    u'formattedLocation': u'San Diego, CA',
#    u'formattedLocationFull': u'San Diego, CA 92129',
#    u'formattedRelativeTime': u'7 days ago',
#    u'indeedApply': False,
#    u'jobkey': u'e3f0a8f2d40232d5',
#    u'jobtitle': u'Data Scientist/Machine Learning Engineer',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'Uses predictive modeling, statistics, Machine Learning, <b>Data</b> Mining, and other <b>data</b> analysis techniques to collect, explore, and extract insights from structure...',
#    u'source': u'Intel',
#    u'sponsored': False,
#    u'state': u'CA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=e3f0a8f2d40232d5&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Houston',
#    u'company': u'Exxon Mobil',
#    u'country': u'US',
#    u'date': u'Wed, 05 Oct 2016 20:01:42 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Houston, TX',
#    u'formattedLocationFull': u'Houston, TX',
#    u'formattedRelativeTime': u'30+ days ago',
#    u'indeedApply': False,
#    u'jobkey': u'857a318d918bc7ce',
#    u'jobtitle': u'Data Scientist',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u'Experience in relevant areas of scientific expertise (e.g., machine learning, numerical methods, signal processing, statistics, mathematics, and optimization)....',
#    u'source': u'Exxon Mobil',
#    u'sponsored': False,
#    u'state': u'TX',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=857a318d918bc7ce&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'},
#   {u'city': u'Redmond',
#    u'company': u'Microsoft',
#    u'country': u'US',
#    u'date': u'Sun, 23 Oct 2016 06:18:14 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Redmond, WA',
#    u'formattedLocationFull': u'Redmond, WA 98052',
#    u'formattedRelativeTime': u'23 days ago',
#    u'indeedApply': False,
#    u'jobkey': u'6d3fbee2fc6b3f54',
#    u'jobtitle': u'Data Scientist',
#    u'onmousedown': u"indeed_clk(this,'1395');",
#    u'snippet': u"In addition, you'll lead the creation of a cooperative learning trust across the individual studios, in order to define and implement best practices for modern...",
#    u'source': u'Microsoft',
#    u'sponsored': False,
#    u'state': u'WA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/viewjob?jk=6d3fbee2fc6b3f54&qd=-uBlOTcviYUPvF9WWwNLo1LeRMwGjuSJSMhqvrrvSnF5PzQUp1CeZFmyalZ3prz5fXoSOkx7sqD5_7LNmejfIlkkrgrsGWWjwQf3yLKOrPM&indpubnum=1892653611555585&atk=1b1lb19braf90ckj'}],
#  u'start': 1,
#  u'totalResults': 15948,
#  u'version': 2}

# %%
from indeed import IndeedClient

client = IndeedClient('1892653611555585')

job_response = client.jobs(jobkeys = ("a3a698868b9b8761", "677cf527dcc5c687"))

job_response
# Out:
# {u'results': [{u'city': u'Seattle',
#    u'company': u'Big Fish',
#    u'country': u'US',
#    u'date': u'Fri, 11 Nov 2016 02:04:50 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Seattle, WA',
#    u'formattedLocationFull': u'Seattle, WA',
#    u'formattedRelativeTime': u'4 days ago',
#    u'indeedApply': False,
#    u'jobkey': u'a3a698868b9b8761',
#    u'jobtitle': u'Data Scientist I',
#    u'latitude': 47.604397,
#    u'longitude': -122.32967,
#    u'onmousedown': u"indeed_clk(this,'');",
#    u'recommendations': [],
#    u'snippet': u'Our facilities are built around work and play, with state of the art tools and software, and amenities that make work fun! Bachelor\u2019s degree or 2-3 years equivalent work experience in Computer Science or related discipline such as Statistics, Mathematics, Economics, etc. Big Fish is home to six individual studios, each with its own unique style of game-play....',
#    u'source': u'Big Fish',
#    u'sponsored': False,
#    u'state': u'WA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/rc/clk?jk=a3a698868b9b8761&atk='},
#   {u'city': u'Los Angeles',
#    u'company': u'Faraday Future, Inc.',
#    u'country': u'US',
#    u'date': u'Thu, 10 Nov 2016 18:00:06 GMT',
#    u'expired': False,
#    u'formattedLocation': u'Los Angeles, CA',
#    u'formattedLocationFull': u'Los Angeles, CA',
#    u'formattedRelativeTime': u'4 days ago',
#    u'indeedApply': False,
#    u'jobkey': u'677cf527dcc5c687',
#    u'jobtitle': u'Data Scientist',
#    u'latitude': 34.052197,
#    u'longitude': -118.24176,
#    u'onmousedown': u"indeed_clk(this,'');",
#    u'recommendations': [],
#    u'snippet': u'Masters in Statistics, Biostatistics, Computer Science, Applied Mathematics or related field \xb7 Extensive experience with R and Python \xb7 Very familiar with Unix and high performance computing \xb7 Deep understanding of statistical modeling, regression, hypothesis testing, estimation, monte carlo simulation, MCMC, Bootstrapping, PCA. PhD in Statistics, Biostatistics, Computer Science, Applied...',
#    u'source': u'Faraday Future, Inc.',
#    u'sponsored': False,
#    u'state': u'CA',
#    u'stations': u'',
#    u'url': u'http://www.indeed.com/rc/clk?jk=677cf527dcc5c687&atk='}],
#  u'version': 2}
